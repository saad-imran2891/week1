# %% [markdown]
# <a href="https://colab.research.google.com/github/saad-imran2891/week1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saad-imran2891/week1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
Lane: Refresh / Content Opportunity Scoring

I'm picking this lane because in notebook 02 I already built the
starting pieces for it a hand-written stale x visible rule and a
decision tree that beats it on Precision@50. This lane's core question
(which pages should be reviewed first) is exactly what that exercise
was doing, so I'm continuing something I already have working
intuition for instead of starting a new direction from zero.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision this improves: which pages a content team reviews first
# for refresh, expansion, or pruning, out of thousands of pages they
# don't have time to check manually.
# Who acts on it: a content/SEO team lead deciding where to spend
# limited review hours this week.
# Cost of a wrong call: if the ranking puts a healthy page at the top,
# the team wastes review time on something that didn't need it. If it
# misses a genuinely declining page, that page keeps losing traffic
# unnoticed until the next audit cycle - a quieter but more expensive
# mistake since lost visibility compounds over time.

# %%
import os, subprocess

REPO_URL = "https://github.com/saad-imran2891/week1"
REPO_DIR = "week1"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
os.chdir(REPO_DIR)

print("Now in:", os.getcwd())
print(os.listdir())
# Out:
# Now in: /content/week1
# ['submission', 'DATA_USE.md', 'notebooks', '.github', 'outputs', 'GUIDE.md', 'requirements.txt', 'CLAUDE.md', 'docs', 'scripts', 'README.md', 'skills', 'data', 'SETUP.md', 'AGENTS.md', '.gitignore', 'LICENSE', 'work', '.git']

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.shape[0], "pages total")
print("declining rate:", round((df["trend_direction"] == "down").mean(), 3))
# Out:
# 30000 pages total
# declining rate: 0.542

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Even a small slice of this data shows the scoring problem is real
# and non-trivial: a meaningful share of pages are declining, keyword
# search volume barely predicts actual traffic (near-zero correlation,
# confirmed in notebook 01), and word count doesn't separate declining
# from growing pages either. None of the obvious, cheap-to-check signals
# solve this alone - which is exactly why a scored ranking approach is
# worth building instead of a simple manual checklist.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Rows:", df.shape[0])
print("Declining rate:", round((df["trend_direction"] == "down").mean(), 3))
print("Pages with 0 impressions_90d:", (df["impressions_90d"] == 0).sum())
print("Median word count, declining vs growing:")
print(df.groupby("trend_direction")["word_count"].median())
# Out:
# Rows: 30000
# Declining rate: 0.542
# Pages with 0 impressions_90d: 0
# Median word count, declining vs growing:
# trend_direction
# down      2909.0
# flat      2698.5
# new       2239.0
# stable    2912.5
# up        2847.5
# Name: word_count, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
What I can say: this is an observed, directional signal for review
prioritization - based on patterns like staleness, visibility, and
engagement in historical data. It's decision support, not a verdict.

What I can't say: I cannot claim this predicts what Google's ranking
algorithm will do, and a page flagged as "declining" is not guaranteed
to improve if refreshed - refreshing might help, might do nothing, or
the decline might have a cause the model can't see (a competitor
outranking it, a seasonal dip, etc). The model tells you where to
look, not what will happen if you act.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
